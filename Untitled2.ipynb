# %%
import pandas as pd

# %%
data=pd.read_csv("final.csv")

# %%
data
# Out:
#      Unnamed: 0  slno       firstname          middle      lastname  \
# 0             0     1  ALLADA VIKITH      SAI CHANDRA         KUMAR
# 1             1     2          ANGANI           DURGA        PRASAD
# 2             2     3           Ajaya           Ravali  Annapaneni
# 3             3     4             Sai         Lakshmi   Annapaneni
# 4             4     5        SWAROOPA              NaN     BADIPATI
# ..          ...   ...             ...              ...          ...
# 229         229   228          Sonali        Vallabhu           NaN
# 230         230   229     Krishna sai        Varigalla          NaN
# 231         231   230      cheedirala  hema pravallika          NaN
# 232         232   231   Sowmya Singh          Kshatri           NaN
# 233         233   232       Saida Rao            Mende          NaN
#
#                             email  paswords
# 0              Vikith99@gmail.com  ?1Mw9wb9
# 1    durgaprasadsiva666@gmail.com  (QAx0nj=
# ...

# %%
data.lastname
# Out:
# 0            KUMAR
# 1           PRASAD
# 2      Annapaneni
# 3      Annapaneni
# 4         BADIPATI
#           ...
# 229            NaN
# 230            NaN
# 231            NaN
# 232            NaN
# 233            NaN
# Name: lastname, Length: 234, dtype: object

# %%
names=data["firstname"].tolist()
emails=data["email"].tolist()
paswords=data["paswords"].tolist()

# %%
paswords
# Out:
# ['?1Mw9wb9',
#  '(QAx0nj=',
#  'R62A)%Du',
#  'TQ=uor5d',
#  '5ruE>ow/',
#  'Pw@Okz1|',
#  '<3Da>581',
#  '#/4N#z|c',
#  'a7dcE|zS',
#  'p1#OJq)J',
#  '1CIud*|G',
#  'Y%4h0X@=',
#  '4hvWVaB|',
#  'Zqs)<N4M',
#  '$1x0e5BD',
#  '9h1~=eUS',
#  '92|y1GaM',
#  '<sVr%t8V',
#  '4~A~Nf|Q',
#  'g01d.F(|',
#  'RWm*)4TB',
#  '8Sxh=Iz:',
#  'MzI::b16',
#  '0|55a3Rx',
#  '=/Kw(s5w',
#  '%BYQm9rM',
#  'rf~V~f9%',
#  'T=dM6Mcn',
#  '/i$z0@SN',
#  'Q<0@fu2V',
#  'znA3Y(bA',
#  'q@rnF=V0',
#  '23/w7$S)',
#  'v=hjMW3U',
#  '0(QM$v.u',
#  'zi>.tXA9',
#  'b)m(zn9Y',
#  '/KdUac~0',
#  'Gwx4<7AO',
#  'I?e8eeGv',
#  '@rBf~7rV',
#  'x6R|5nM>',
#  'IDWZ%01f',
#  'th><fnA3',
#  'b*k7BBk5',
#  'Q$0c1?>F',
#  '8d(kE|=<',
#  'JQI.zO5J',
#  'tHeK/)F1',
#  '~FT*sA34',
#  'B~V5dFi(',
#  'QDGxF)W4',
#  'PN5M%WCd',
#  '1::<.aJ|',
#  'G9<*HwKo',
#  '(8KpYf=E',
#  'K#.x4Gh~',
#  '5PIX<Pep',
#  '(<y6UdBj',
#  'WzZ$v3/K',
#  'TsdP0C#d',
#  '%D>N0g<N',
#  '7s1m#QIr',
#  'PzW/Iqd6',
#  'a8@IHvg2',
#  'u:6iGnmr',
# ...

# %%
requried_data=[]
for i in range(len(names)):
    
    requried_data.append([names[i],emails[i],paswords[i]])

# %%
requried_data
# Out:
# [['ALLADA VIKITH ', 'Vikith99@gmail.com', '?1Mw9wb9'],
#  ['ANGANI', 'durgaprasadsiva666@gmail.com', '(QAx0nj='],
#  ['Ajaya', 'ajayaravali985@gmail.com', 'R62A)%Du'],
#  ['Sai', 'sailakshmi985@gmail.com', 'TQ=uor5d'],
#  ['SWAROOPA', 'swaroopabadipati@gmail.com', '5ruE>ow/'],
#  ['BUDUMURU ', 'syamsundar.1307@gmail.com ', 'Pw@Okz1|'],
#  ['Bujja', 'rockingravinri123@gmail.com', '<3Da>581'],
#  ['Bunga', 'saiharishbunga04@gmail.com', '#/4N#z|c'],
#  ['RAHUL', 'channarahul10@gmail.com', 'a7dcE|zS'],
#  ['DURGA', 'prasaddnp97@gmail.com', 'p1#OJq)J'],
#  ['RAGHAVA', 'Raghavgopasina@outlook.com', '1CIud*|G'],
#  ['AJAY ', 'ajayshankar969@gmail.com', 'Y%4h0X@='],
#  ['Jarugulla', 'ramanajaragulla@gmail.com ', '4hvWVaB|'],
#  ['Kalidindi', 'vasantha.k1998@gmail.com', 'Zqs)<N4M'],
#  ['KANCHARLA', 'durgakancharla24@gmail.com', '$1x0e5BD'],
#  ['KANTUMUTCHU', 'trushalsai@gmail.com', '9h1~=eUS'],
#  ['UMA SAI', 'dp1317056.1@gmail.com', '92|y1GaM'],
# ...
